# %% [markdown]
# # API Data Collection
#
# This notebook details the collection of necessary data from the Youtube API.
#
# We would like to source our data from various political news sources:
#
# - CNN
# - MSNBC
# - ABC
# - Reuters
# - FOX
# - Tucker Carlson
# - The Daily Wire

# %% [markdown]
# ## 0. Import Dependencies

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
scopes = ["https://www.googleapis.com/auth/youtube.readonly"]

from dotenv import load_dotenv
import os
import sys
from pathlib import Path

from typing import List, Dict, Any, Optional
from typing_extensions import TypedDict
from datetime import datetime

from pprint import pprint

sys.path.append(Path(os.path.abspath(os.getcwd())).parent) # Get project root directory for .env file
load_dotenv()
# Out:
# True

# %% [markdown]
# ## 1. API Configuration/Exploration
#
# We test for the API functionality. Here, we would make a small example of receiving information from the Youtube API

# %%
CHANNEL_HANDLES = [
    "msnbc",
    "cnn",
    "FoxNews",
    "briantylercohen",
    "DailyWirePlus",
    "ABCNews",
    "TuckerCarlson"
]

# %%
API_KEY = os.getenv("GOOGLE_API_KEY")
API_VERSION = "v3"
API_SERVICE_NAME = "youtube"

youtube = build(API_SERVICE_NAME, API_VERSION, developerKey=API_KEY)

# %%
from functools import wraps

def api_status_handler(f: callable):
    @wraps(f)
    def wrapper(*args, **kwargs):
        try:
            return {
                "status_code": 200,
                "data": f(*args, **kwargs)
            }
        except HttpError as e:
            status_code = e.resp.status
            error_content = e.content.decode("utf-8")
            print(f"HTTP Error {status_code}: {error_content}")
            
            if status_code == 403:
                print("Comments disabled or quota exceeded")
            elif status_code == 404:
                print("Video not found")
            elif status_code == 400:
                print("Invalid video ID")
            
            return {
                "status_code": status_code
            }

    return wrapper

# %% [markdown]
# ### 1.1 Retrieving Youtube Channel

# %%
@api_status_handler
def get_channel(handle: str):
    # Create request via the Google API (This is a quite convenient abstraction)
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        forHandle=handle
    )

    channel_response = request.execute()
    return channel_response

response = get_channel(CHANNEL_HANDLES[0])
if response["status_code"] == 200:
    channel = response["data"]
else:
    channel = {}
pprint(channel)
# Out:
# {'etag': 'p097-GXn5FKgAptEff-v5n7UpIc',
#  'items': [{'contentDetails': {'relatedPlaylists': {'likes': '',
#                                                     'uploads': 'UUaXkIU1QidjPwiAYu6GcHjg'}},
#             'etag': 'updSCvQ6eNwbLQTPjXjgHL5sTRY',
#             'id': 'UCaXkIU1QidjPwiAYu6GcHjg',
#             'kind': 'youtube#channel',
#             'snippet': {'customUrl': '@msnbc',
#                         'description': 'The official MSNBC YouTube Channel. '
#                                        'MSNBC is the premier destination for '
#                                        'in-depth analysis of the news, '
#                                        'insightful political commentary and '
#                                        'diverse perspectives. \n',
#                         'localized': {'description': 'The official MSNBC '
#                                                      'YouTube Channel. MSNBC '
#                                                      'is the premier '
#                                                      'destination for in-depth '
#                                                      'analysis of the news, '
#                                                      'insightful political '
#                                                      'commentary and diverse '
#                                                      'perspectives. \n',
#                                       'title': 'MSNBC'},
#                         'publishedAt': '2011-12-01T19:16:09Z',
#                         'thumbnails': {'default': {'height': 88,
#                                                    'url': 'https://yt3.ggpht.com/Kn00Sgjs6hlFbGtbYmE2bqMrGr_Gbz062eFK_fnVfziUN4HZ2C6I988wsfARNEcFwBB_5rARdw=s88-c-k-c0x00ffffff-no-rj',
#                                                    'width': 88},
#                                        'high': {'height': 800,
#                                                 'url': 'https://yt3.ggpht.com/Kn00Sgjs6hlFbGtbYmE2bqMrGr_Gbz062eFK_fnVfziUN4HZ2C6I988wsfARNEcFwBB_5rARdw=s800-c-k-c0x00ffffff-no-rj',
#                                                 'width': 800},
#                                        'medium': {'height': 240,
#                                                   'url': 'https://yt3.ggpht.com/Kn00Sgjs6hlFbGtbYmE2bqMrGr_Gbz062eFK_fnVfziUN4HZ2C6I988wsfARNEcFwBB_5rARdw=s240-c-k-c0x00ffffff-no-rj',
#                                                   'width': 240}},
#                         'title': 'MSNBC'},
#             'statistics': {'hiddenSubscriberCount': False,
#                            'subscriberCount': '9230000',
#                            'videoCount': '103979',
#                            'viewCount': '17919777681'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 1}}

# %% [markdown]
# ### 1.2 Retrieving Channel's Uploads

# %%
# Retrieve the uploads playlist ID for playlistItems() request
@api_status_handler
def get_channel_uploads(uploads_playlist_id: str):
    request = youtube.playlistItems().list(
        part="contentDetails,id,snippet,status",
        playlistId=uploads_playlist_id,
    )

    uploads_response = request.execute()
    return uploads_response

playlist_id = channel["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
response = get_channel_uploads(playlist_id)
if response["status_code"] == 200:
    uploads = response["data"]
else:
    uploads = {}

pprint(uploads)
# Out:
# {'etag': 'Jxz2j242d9zLrizL8YZrQ8_npRA',
#  'items': [{'contentDetails': {'videoId': 'LHfr1qngP-c',
#                                'videoPublishedAt': '2025-10-10T22:41:57Z'},
#             'etag': 'GS-sSaB9WdaHZkl7NFpjT0bn738',
#             'id': 'VVVhWGtJVTFRaWRqUHdpQVl1NkdjSGpnLkxIZnIxcW5nUC1j',
#             'kind': 'youtube#playlistItem',
#             'snippet': {'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'channelTitle': 'MSNBC',
#                         'description': 'The Trump administration announced '
#                                        'that "substantial" layoffs of federal '
#                                        'workers "have begun," as the '
#                                        'government shutdown continues. The '
#                                        'move, according to a White House '
#                                        'official, could impact "thousands." '
#                                        'MSNBC White House correspondent Laura '
#                                        'Barrón-López reports.\n'
#                                        '\n'
#                                        'For more context and news coverage of '
#                                        'the most important stories of our day '
#                                        'click here: https://www.msnbc.com/\n'
#                                        '\n'
#                                        '» Subscribe to MSNBC: '
#                                        'https://www.youtube.com/msnbc\n'
#                                        '» Subscribe to MSNBC on TikTok '
#                                        'https://www.tiktok.com/@msnbc \n'
#                                        '» Subscribe to MSNBC on Instagram '
#                                        'https://www.instagram.com/msnbc \n'
#                                        'Download our new MSNBC app for the '
#                                        'latest breaking news and daily '
#                                        'headlines at a glance: '
#                                        'https://www.msnbc.com/information/download-msnbc-app-n1241692\n'
#                                        '\n'
#                                        'Follow MSNBC Show Blogs \n'
#                                        'MaddowBlog: '
#                                        'https://www.msnbc.com/maddowblog\n'
#                                        '\n'
#                                        'MSNBC delivers breaking news, in-depth '
#                                        'analysis of political headlines, '
#                                        'commentary and informed perspectives. '
#                                        'Find video clips and segments from The '
#                                        'Rachel Maddow Show, Inside with Jen '
#                                        'Psaki, Morning Joe, The Beat, '
#                                        'Deadline: White House, All In, The '
#                                        'Last Word, The 11th Hour, and more.\n'
#                                        '\n'
#                                        'Connect with MSNBC Online \n'
#                                        'Visit msnbc.com: '
#                                        'https://www.msnbc.com/ \n'
#                                        'Subscribe to the MSNBC Daily '
#                                        'Newsletter: '
#                                        'https://link.msnbc.com/join/5ck/msnbc-daily-signup\n'
#                                        '\n'
#                                        '#governmentshutdown #layoffs #trump',
#                         'playlistId': 'UUaXkIU1QidjPwiAYu6GcHjg',
#                         'position': 0,
#                         'publishedAt': '2025-10-10T22:41:57Z',
#                         'resourceId': {'kind': 'youtube#video',
#                                        'videoId': 'LHfr1qngP-c'},
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/LHfr1qngP-c/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/LHfr1qngP-c/hqdefault.jpg',
#                                                 'width': 480},
#                                        'maxres': {'height': 720,
#                                                   'url': 'https://i.ytimg.com/vi/LHfr1qngP-c/maxresdefault.jpg',
#                                                   'width': 1280},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/LHfr1qngP-c/mqdefault.jpg',
#                                                   'width': 320},
#                                        'standard': {'height': 480,
#                                                     'url': 'https://i.ytimg.com/vi/LHfr1qngP-c/sddefault.jpg',
#                                                     'width': 640}},
#                         'title': "Trump WH: Layoffs 'have begun amid shutdown'",
#                         'videoOwnerChannelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'videoOwnerChannelTitle': 'MSNBC'},
#             'status': {'privacyStatus': 'public'}},
#            {'contentDetails': {'videoId': 'JkqbX9xTf1w',
#                                'videoPublishedAt': '2025-10-10T22:29:21Z'},
#             'etag': '_VltN-BECYqxpKQHHoLULBlu6ys',
#             'id': 'VVVhWGtJVTFRaWRqUHdpQVl1NkdjSGpnLkprcWJYOXhUZjF3',
#             'kind': 'youtube#playlistItem',
#             'snippet': {'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'channelTitle': 'MSNBC',
#                         'description': 'Watch live coverage as President Trump '
#                                        'delivers an announcement from the Oval '
#                                        'Office at the White House.\n'
#                                        '\n'
#                                        'For more context and news coverage of '
#                                        'the most important stories of our day '
#                                        'click here: https://www.msnbc.com/\n'
#                                        '\n'
#                                        '» Subscribe to MSNBC: '
#                                        'https://www.youtube.com/msnbc\n'
#                                        '» Subscribe to MSNBC on TikTok '
#                                        'https://www.tiktok.com/@msnbc \n'
#                                        '» Subscribe to MSNBC on Instagram '
#                                        'https://www.instagram.com/msnbc \n'
#                                        'Download our new MSNBC app for the '
#                                        'latest breaking news and daily '
#                                        'headlines at a glance: '
#                                        'https://www.msnbc.com/information/download-msnbc-app-n1241692\n'
#                                        '\n'
#                                        'Follow MSNBC Show Blogs \n'
#                                        'MaddowBlog: '
#                                        'https://www.msnbc.com/maddowblog\n'
#                                        '\n'
#                                        'MSNBC delivers breaking news, in-depth '
#                                        'analysis of political headlines, '
#                                        'commentary and informed perspectives. '
#                                        'Find video clips and segments from The '
#                                        'Rachel Maddow Show, The Briefing with '
#                                        'Jen Psaki, Morning Joe, The Beat, '
#                                        'Deadline: White House, All In, The '
#                                        'Last Word, The 11th Hour, and more.\n'
#                                        '\n'
#                                        'Connect with MSNBC Online \n'
#                                        'Visit msnbc.com: '
#                                        'https://www.msnbc.com/ \n'
#                                        'Subscribe to the MSNBC Daily '
#                                        'Newsletter: '
#                                        'https://link.msnbc.com/join/5ck/msnbc-daily-signup',
#                         'playlistId': 'UUaXkIU1QidjPwiAYu6GcHjg',
#                         'position': 1,
#                         'publishedAt': '2025-10-10T22:29:21Z',
#                         'resourceId': {'kind': 'youtube#video',
#                                        'videoId': 'JkqbX9xTf1w'},
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/JkqbX9xTf1w/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/JkqbX9xTf1w/hqdefault.jpg',
#                                                 'width': 480},
#                                        'maxres': {'height': 720,
#                                                   'url': 'https://i.ytimg.com/vi/JkqbX9xTf1w/maxresdefault.jpg',
#                                                   'width': 1280},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/JkqbX9xTf1w/mqdefault.jpg',
#                                                   'width': 320},
#                                        'standard': {'height': 480,
#                                                     'url': 'https://i.ytimg.com/vi/JkqbX9xTf1w/sddefault.jpg',
#                                                     'width': 640}},
#                         'title': 'LIVE: Trump makes announcement from Oval '
#                                  'Office',
#                         'videoOwnerChannelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'videoOwnerChannelTitle': 'MSNBC'},
#             'status': {'privacyStatus': 'public'}},
#            {'contentDetails': {'videoId': 'H4aCuI7crnw',
#                                'videoPublishedAt': '2025-10-10T22:00:26Z'},
#             'etag': 'M8NQ8M4OYKEp9tnsgAqrBhjxwWs',
#             'id': 'VVVhWGtJVTFRaWRqUHdpQVl1NkdjSGpnLkg0YUN1STdjcm53',
#             'kind': 'youtube#playlistItem',
#             'snippet': {'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'channelTitle': 'MSNBC',
#                         'description': 'New York Attorney General Letitia '
#                                        'James has been charged with bank fraud '
#                                        'and making false statements, sparking '
#                                        'significant legal and political '
#                                        'controversy. MSNBC Justice and '
#                                        'Intelligence Correspondent Ken '
#                                        'Dilanian reports more. Former Deputy '
#                                        'Assistant Attorney General Tom Dupree, '
#                                        'DOJ Criminal Division former Assistant '
#                                        'Attorney General Leslie Caldwell, and '
#                                        'Mark Mckinnon, former Advisor to '
#                                        'George W. Bush and John McCain, join '
#                                        'Katy Tur to break down the charges.\n'
#                                        '\n'
#                                        'Our next MSNBC Live event is on '
#                                        'October 11th in New York City! Buy '
#                                        'Tickets Now: msnbc.com/live25\n'
#                                        '\n'
#                                        'For more context and news coverage of '
#                                        'the most important stories of our day '
#                                        'click here: https://www.msnbc.com/\n'
#                                        '\n'
#                                        '» Subscribe to MSNBC: '
#                                        'https://www.youtube.com/msnbc\n'
#                                        '» Subscribe to MSNBC on TikTok '
#                                        'https://www.tiktok.com/@msnbc \n'
#                                        '» Subscribe to MSNBC on Instagram '
#                                        'https://www.instagram.com/msnbc \n'
#                                        'Download our new MSNBC app for the '
#                                        'latest breaking news and daily '
#                                        'headlines at a glance: '
#                                        'https://www.msnbc.com/information/download-msnbc-app-n1241692\n'
#                                        '\n'
#                                        'Follow MSNBC Show Blogs \n'
#                                        'MaddowBlog: '
#                                        'https://www.msnbc.com/maddowblog\n'
#                                        '\n'
#                                        'MSNBC delivers breaking news, in-depth '
#                                        'analysis of political headlines, '
#                                        'commentary and informed perspectives. '
#                                        'Find video clips and segments from The '
#                                        'Rachel Maddow Show, The Briefing with '
#                                        'Jen Psaki, Morning Joe, The Beat, '
#                                        'Deadline: White House, The Weeknight, '
#                                        'All In, The Last Word, The 11th Hour, '
#                                        'and more.\n'
#                                        '\n'
#                                        'Connect with MSNBC Online \n'
#                                        'Visit msnbc.com: '
#                                        'https://www.msnbc.com/ \n'
#                                        'Subscribe to the MSNBC Daily '
#                                        'Newsletter: '
#                                        'https://link.msnbc.com/join/5ck/msnbc-daily-signup\n'
#                                        '\n'
#                                        '#trump #pambondi',
#                         'playlistId': 'UUaXkIU1QidjPwiAYu6GcHjg',
#                         'position': 2,
#                         'publishedAt': '2025-10-10T22:00:26Z',
#                         'resourceId': {'kind': 'youtube#video',
#                                        'videoId': 'H4aCuI7crnw'},
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/H4aCuI7crnw/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/H4aCuI7crnw/hqdefault.jpg',
#                                                 'width': 480},
#                                        'maxres': {'height': 720,
#                                                   'url': 'https://i.ytimg.com/vi/H4aCuI7crnw/maxresdefault.jpg',
#                                                   'width': 1280},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/H4aCuI7crnw/mqdefault.jpg',
#                                                   'width': 320},
#                                        'standard': {'height': 480,
#                                                     'url': 'https://i.ytimg.com/vi/H4aCuI7crnw/sddefault.jpg',
#                                                     'width': 640}},
#                         'title': 'Ex-Trump lawyer says Bondi is ‘more '
#                                  "reprehensible’ than Nixon's AG",
#                         'videoOwnerChannelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'videoOwnerChannelTitle': 'MSNBC'},
#             'status': {'privacyStatus': 'public'}},
#            {'contentDetails': {'videoId': '5zroLgAcCmY',
#                                'videoPublishedAt': '2025-10-10T21:58:18Z'},
#             'etag': 'KUT18RAJj5fItksl3vpZ_EWS1a4',
#             'id': 'VVVhWGtJVTFRaWRqUHdpQVl1NkdjSGpnLjV6cm9MZ0FjQ21Z',
#             'kind': 'youtube#playlistItem',
#             'snippet': {'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'channelTitle': 'MSNBC',
#                         'description': 'Reverend David Black, Minister of the '
#                                        'First Presbyterian Church of Chicago '
#                                        'who was shot in the head with pepper '
#                                        'balls while praying in front of an ICE '
#                                        'facility and Reverend Quincy '
#                                        'Worthington, Pastor of Highland Park '
#                                        'Presbyterian Church who has also been '
#                                        'at the protests and endured pepper '
#                                        'bullets and tear gas while there join '
#                                        'Nicolle Wallace on Deadline White '
#                                        'House to discuss their experiences '
#                                        'while protesting against ICE presences '
#                                        'in their communities.\xa0\n'
#                                        '\n'
#                                        'Our next MSNBC Live event is on '
#                                        'October 11th in New York City! Buy '
#                                        'Tickets Now: msnbc.com/live25\n'
#                                        '\n'
#                                        'For more context and news coverage of '
#                                        'the most important stories of our day '
#                                        'click here: https://www.msnbc.com/\n'
#                                        '\n'
#                                        '» Subscribe to MSNBC: '
#                                        'https://www.youtube.com/msnbc\n'
#                                        '» Subscribe to MSNBC on TikTok '
#                                        'https://www.tiktok.com/@msnbc \n'
#                                        '» Subscribe to MSNBC on Instagram '
#                                        'https://www.instagram.com/msnbc \n'
#                                        'Download our new MSNBC app for the '
#                                        'latest breaking news and daily '
#                                        'headlines at a glance: '
#                                        'https://www.msnbc.com/information/download-msnbc-app-n1241692\n'
#                                        '\n'
#                                        'Follow MSNBC Show Blogs \n'
#                                        'MaddowBlog: '
#                                        'https://www.msnbc.com/maddowblog\n'
#                                        '\n'
#                                        'MSNBC delivers breaking news, in-depth '
#                                        'analysis of political headlines, '
#                                        'commentary and informed perspectives. '
#                                        'Find video clips and segments from The '
#                                        'Rachel Maddow Show, The Briefing with '
#                                        'Jen Psaki, Morning Joe, The Beat, '
#                                        'Deadline: White House, The Weeknight, '
#                                        'All In, The Last Word, The 11th Hour, '
#                                        'and more.\n'
#                                        '\n'
#                                        'Connect with MSNBC Online \n'
#                                        'Visit msnbc.com: '
#                                        'https://www.msnbc.com/ \n'
#                                        'Subscribe to the MSNBC Daily '
#                                        'Newsletter: '
#                                        'https://link.msnbc.com/join/5ck/msnbc-daily-signup\n'
#                                        '\n'
#                                        '#religion #ice #immigration',
#                         'playlistId': 'UUaXkIU1QidjPwiAYu6GcHjg',
#                         'position': 3,
#                         'publishedAt': '2025-10-10T21:58:18Z',
#                         'resourceId': {'kind': 'youtube#video',
#                                        'videoId': '5zroLgAcCmY'},
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/5zroLgAcCmY/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/5zroLgAcCmY/hqdefault.jpg',
#                                                 'width': 480},
#                                        'maxres': {'height': 720,
#                                                   'url': 'https://i.ytimg.com/vi/5zroLgAcCmY/maxresdefault.jpg',
#                                                   'width': 1280},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/5zroLgAcCmY/mqdefault.jpg',
#                                                   'width': 320},
#                                        'standard': {'height': 480,
#                                                     'url': 'https://i.ytimg.com/vi/5zroLgAcCmY/sddefault.jpg',
#                                                     'width': 640}},
#                         'title': 'Religious leaders speak out about being '
#                                  'attacked while protesting ICE in their '
#                                  'communities',
#                         'videoOwnerChannelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'videoOwnerChannelTitle': 'MSNBC'},
#             'status': {'privacyStatus': 'public'}},
#            {'contentDetails': {'videoId': 'TneWtHv0wbU',
#                                'videoPublishedAt': '2025-10-10T21:30:09Z'},
#             'etag': 'PwOXr7iEDGg-3vg7KiWSZ-wFhh8',
#             'id': 'VVVhWGtJVTFRaWRqUHdpQVl1NkdjSGpnLlRuZVd0SHYwd2JV',
#             'kind': 'youtube#playlistItem',
#             'snippet': {'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'channelTitle': 'MSNBC',
#                         'description': 'A ceasefire agreement between Israel '
#                                        'and Hamas is now in effect in Gaza '
#                                        'after the two sides agreed to the '
#                                        'first phase of a peace deal. President '
#                                        'Emeritus of the Council on Foreign '
#                                        'Relations Richard Haass and Senior '
#                                        'Fellow of Middle East and Africa '
#                                        'Studies at the Council on Foreign '
#                                        'Relations Steven Cook join Katy Tur to '
#                                        'share their outlook for the conflict.\n'
#                                        '\n'
#                                        'Our next MSNBC Live event is on '
#                                        'October 11th in New York City! Buy '
#                                        'Tickets Now: msnbc.com/live25\n'
#                                        '\n'
#                                        'For more context and news coverage of '
#                                        'the most important stories of our day '
#                                        'click here: https://www.msnbc.com/\n'
#                                        '\n'
#                                        '» Subscribe to MSNBC: '
#                                        'https://www.youtube.com/msnbc\n'
#                                        '» Subscribe to MSNBC on TikTok '
#                                        'https://www.tiktok.com/@msnbc \n'
#                                        '» Subscribe to MSNBC on Instagram '
#                                        'https://www.instagram.com/msnbc \n'
#                                        'Download our new MSNBC app for the '
#                                        'latest breaking news and daily '
#                                        'headlines at a glance: '
#                                        'https://www.msnbc.com/information/download-msnbc-app-n1241692\n'
#                                        '\n'
#                                        'Follow MSNBC Show Blogs \n'
#                                        'MaddowBlog: '
#                                        'https://www.msnbc.com/maddowblog\n'
#                                        '\n'
#                                        'MSNBC delivers breaking news, in-depth '
#                                        'analysis of political headlines, '
#                                        'commentary and informed perspectives. '
#                                        'Find video clips and segments from The '
#                                        'Rachel Maddow Show, The Briefing with '
#                                        'Jen Psaki, Morning Joe, The Beat, '
#                                        'Deadline: White House, The Weeknight, '
#                                        'All In, The Last Word, The 11th Hour, '
#                                        'and more.\n'
#                                        '\n'
#                                        'Connect with MSNBC Online \n'
#                                        'Visit msnbc.com: '
#                                        'https://www.msnbc.com/ \n'
#                                        'Subscribe to the MSNBC Daily '
#                                        'Newsletter: '
#                                        'https://link.msnbc.com/join/5ck/msnbc-daily-signup\n'
#                                        '\n'
#                                        '#israel #middleeast #netanyahu',
#                         'playlistId': 'UUaXkIU1QidjPwiAYu6GcHjg',
#                         'position': 4,
#                         'publishedAt': '2025-10-10T21:30:09Z',
#                         'resourceId': {'kind': 'youtube#video',
#                                        'videoId': 'TneWtHv0wbU'},
#                         'thumbnails': {'default': {'height': 90,
#                                                    'url': 'https://i.ytimg.com/vi/TneWtHv0wbU/default.jpg',
#                                                    'width': 120},
#                                        'high': {'height': 360,
#                                                 'url': 'https://i.ytimg.com/vi/TneWtHv0wbU/hqdefault.jpg',
#                                                 'width': 480},
#                                        'maxres': {'height': 720,
#                                                   'url': 'https://i.ytimg.com/vi/TneWtHv0wbU/maxresdefault.jpg',
#                                                   'width': 1280},
#                                        'medium': {'height': 180,
#                                                   'url': 'https://i.ytimg.com/vi/TneWtHv0wbU/mqdefault.jpg',
#                                                   'width': 320},
#                                        'standard': {'height': 480,
#                                                     'url': 'https://i.ytimg.com/vi/TneWtHv0wbU/sddefault.jpg',
#                                                     'width': 640}},
#                         'title': "'A lot of hope' but 'the hard work has yet "
#                                  "to begin' in Gaza: Foreign policy expert",
#                         'videoOwnerChannelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'videoOwnerChannelTitle': 'MSNBC'},
#             'status': {'privacyStatus': 'public'}}],
#  'kind': 'youtube#playlistItemListResponse',
#  'nextPageToken': 'EAAaHlBUOkNBVWlFREUwUmpNeFJUVkZPVGcyTkVORk5VSQ',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 20000}}

# %% [markdown]
# ### 1.3 Paginating Through Channel Uploads
#
# We can expand upon the above section by paginating through for more pages

# %%
next_page_token = ""
for i in range(5):
    request = youtube.playlistItems().list(
        part="contentDetails,id,snippet,status",
        playlistId=playlist_id,
        pageToken=next_page_token
    )
    
    page_response = request.execute()
    next_page_token = page_response["nextPageToken"]
    
    print(f"NextPageToken: {next_page_token}")
# Out:
# NextPageToken: EAAaHlBUOkNBVWlFREUwUmpNeFJUVkZPVGcyTkVORk5VSQ
# NextPageToken: EAAaHlBUOkNBb2lFRVF3UWpKRU9FSXdNVVZHTURNMk9FRQ
# NextPageToken: EAAaHlBUOkNBOGlFRFpETlRBek5rWTRNMEkwUmpGRk9ERQ
# NextPageToken: EAAaHlBUOkNCUWlFREkyTkRVM05ETTNOa0ZEUVVFd056Zw
# NextPageToken: EAAaHlBUOkNCa2lFRUkxT1RkRU4wSkdNall3TVRRek1UTQ

# %% [markdown]
# ### 1.4 Comment Section Retrieval
#
# Now that we have access to the video lists, we can obtain the comments under specific videos

# %%
request = youtube.playlistItems().list(
    part="contentDetails,id,snippet,status",
    playlistId=playlist_id,
)
video_list_response = request.execute()

# Get a single item from the list and its video ID
video_id = video_list_response["items"][3]["contentDetails"]["videoId"]

# %%
video_id
# Out:
# '5zroLgAcCmY'

# %%
@api_status_handler
def get_comment_thread(video_id: str):
    # Get the comment thread
    request = youtube.commentThreads().list(
        part="id,replies,snippet",
        videoId=video_id
    )
    comment_thread_response = request.execute()
    return comment_thread_response

response = get_comment_thread(video_id)

if response["status_code"] == 200:
    comment_thread = response["data"]
else:
    comment_thread = {}
pprint(comment_thread)
# Out:
# {'etag': 'xiCyplm8EETPwKPGFL84VLqt4rg',
#  'items': [{'etag': 'te_ZzwOCuXWLoNy_4V0tXPnECHs',
#             'id': 'UgwMczLTEV4RCfursEV4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'YT2ZX2_nRMHMEKCi94Gxhzho3PU',
#                                             'id': 'UgwMczLTEV4RCfursEV4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCAFB0tUYdwlKJ8p2CE1U_Ww'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@deanbeavers7372',
#                                                         'authorDisplayName': '@deanbeavers7372',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mN2msNjVGEFg0gWwUIwCJDqNCb0mhaBSB01SU9c2E=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2025-10-10T23:15:56Z',
#                                                         'textDisplay': 'Religious '
#                                                                        'leaders '
#                                                                        'need '
#                                                                        'to '
#                                                                        'look a '
#                                                                        'little '
#                                                                        'closer '
#                                                                        'at the '
#                                                                        'bible, '
#                                                                        'Illegal '
#                                                                        'is '
#                                                                        'wrong.',
#                                                         'textOriginal': 'Religious '
#                                                                         'leaders '
#                                                                         'need '
#                                                                         'to '
#                                                                         'look '
#                                                                         'a '
#                                                                         'little '
#                                                                         'closer '
#                                                                         'at '
#                                                                         'the '
#                                                                         'bible, '
#                                                                         'Illegal '
#                                                                         'is '
#                                                                         'wrong.',
#                                                         'updatedAt': '2025-10-10T23:15:56Z',
#                                                         'videoId': '5zroLgAcCmY',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': '5zroLgAcCmY'}},
#            {'etag': '-FioMIyq1Qtf2Rg5PTcFFArdANE',
#             'id': 'Ugye6TKFoKSRjHt5aM94AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'Il2vPpOMiPl3He4wj3EKR5obYjU',
#                                             'id': 'Ugye6TKFoKSRjHt5aM94AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UC-yNoPF8yTUYRE7eBMSciaQ'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@romanrivera7418',
#                                                         'authorDisplayName': '@romanrivera7418',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lrxTdvHpeu49cWh7DpHiSvCWXkiyAkzXYtN5u8os458So=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2025-10-10T23:15:56Z',
#                                                         'textDisplay': 'Govt '
#                                                                        'Shooting '
#                                                                        'Christian’s '
#                                                                        'Now!',
#                                                         'textOriginal': 'Govt '
#                                                                         'Shooting '
#                                                                         'Christian’s '
#                                                                         'Now!',
#                                                         'updatedAt': '2025-10-10T23:15:56Z',
#                                                         'videoId': '5zroLgAcCmY',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': '5zroLgAcCmY'}},
#            {'etag': '3bEDw0mlErddd3aZdhIZnXWE-Qo',
#             'id': 'UgwHrZYFRd63oOV-3aV4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'sUxB4ZPzbkKy3-fQvlLRn-VWzmw',
#                                             'id': 'UgwHrZYFRd63oOV-3aV4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCBQ14890FjxI5vp6xbkAAvw'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@Pasha.Redfeather',
#                                                         'authorDisplayName': '@Pasha.Redfeather',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/6d39Bh-ofaQR8GyiyjrDbwMv62Ai-D98DratyJgP9NaQE9-ge75EGp_i-e5fKVoe9fb_sQvC7hE=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2025-10-10T23:15:34Z',
#                                                         'textDisplay': 'Trump '
#                                                                        'needs '
#                                                                        'to '
#                                                                        'hang '
#                                                                        'for '
#                                                                        'treason '
#                                                                        'he’s '
#                                                                        'guilty!!! '
#                                                                        'WE '
#                                                                        'HAVE '
#                                                                        'ALL '
#                                                                        'WATCHED '
#                                                                        'HIM '
#                                                                        'COMMIT '
#                                                                        'TREASON!!!!!',
#                                                         'textOriginal': 'Trump '
#                                                                         'needs '
#                                                                         'to '
#                                                                         'hang '
#                                                                         'for '
#                                                                         'treason '
#                                                                         'he’s '
#                                                                         'guilty!!! '
#                                                                         'WE '
#                                                                         'HAVE '
#                                                                         'ALL '
#                                                                         'WATCHED '
#                                                                         'HIM '
#                                                                         'COMMIT '
#                                                                         'TREASON!!!!!',
#                                                         'updatedAt': '2025-10-10T23:16:03Z',
#                                                         'videoId': '5zroLgAcCmY',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': '5zroLgAcCmY'}},
#            {'etag': '6pcssCMtNMJ7JF0LOMFd9l5PbWc',
#             'id': 'UgyNrL1oWoG1d6o27eF4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'mQyGX70yyyd7M5fpaErfZoCZ1os',
#                                             'id': 'UgyNrL1oWoG1d6o27eF4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UC1Pac28VIX-faEpw6irK1jQ'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@chrisddawson',
#                                                         'authorDisplayName': '@chrisddawson',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lT8kMlKVnSLTjq1-RUalUFrPHGU6ypiW8jqr2SXHY=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2025-10-10T23:15:03Z',
#                                                         'textDisplay': 'We '
#                                                                        'can’t '
#                                                                        'let '
#                                                                        'the '
#                                                                        'United '
#                                                                        'States '
#                                                                        'go '
#                                                                        'down '
#                                                                        'like '
#                                                                        'trumps '
#                                                                        'casinos',
#                                                         'textOriginal': 'We '
#                                                                         'can’t '
#                                                                         'let '
#                                                                         'the '
#                                                                         'United '
#                                                                         'States '
#                                                                         'go '
#                                                                         'down '
#                                                                         'like '
#                                                                         'trumps '
#                                                                         'casinos',
#                                                         'updatedAt': '2025-10-10T23:15:03Z',
#                                                         'videoId': '5zroLgAcCmY',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': '5zroLgAcCmY'}},
#            {'etag': 'xRokppLVeFMogCiSEuEEyQmzWNM',
#             'id': 'UgxOMMN6fMq23BU0uSR4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': '3c41CnPKzRILh5-XSM-gqq3vVeI',
#                                             'id': 'UgxOMMN6fMq23BU0uSR4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCKoOXrdJ8G444u7VYhQ6olQ'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@randywheeler3914',
#                                                         'authorDisplayName': '@randywheeler3914',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/arFjwRO3FDns5UA8nQztY7596DWe9i-unxfFPU26ySrl00jPM3yYth5wsRVG7r4rSYSVYac1=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2025-10-10T23:15:00Z',
#                                                         'textDisplay': 'He was '
#                                                                        'blocking '
#                                                                        'the '
#                                                                        'driveway',
#                                                         'textOriginal': 'He '
#                                                                         'was '
#                                                                         'blocking '
#                                                                         'the '
#                                                                         'driveway',
#                                                         'updatedAt': '2025-10-10T23:15:00Z',
#                                                         'videoId': '5zroLgAcCmY',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': '5zroLgAcCmY'}},
#            {'etag': '_pp0c9kTLWTMpVHRYOOtL6CdUNM',
#             'id': 'Ugwb5-Z-NBJmWXzLp7F4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': '9AndLipySgooTzco4WK1vOTQwIU',
#                                             'id': 'Ugwb5-Z-NBJmWXzLp7F4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCVjNimKdZXdZ8qc4lIRkYWw'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@OG.REDI-410',
#                                                         'authorDisplayName': '@OG.REDI-410',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/KgxBOdyn5xNkgzvX7BAVe8x0q1qsv2Kv8doYbN8ew1_xGD-iZykKjHi6WdAg8vTn2CO0wo8m=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2025-10-10T23:14:28Z',
#                                                         'textDisplay': 'Trumps '
#                                                                        'Presidency '
#                                                                        'has '
#                                                                        'similarities '
#                                                                        'to '
#                                                                        'Henry '
#                                                                        'VIII '
#                                                                        'reign '
#                                                                        'in '
#                                                                        'England! '
#                                                                        'How he '
#                                                                        'pushed '
#                                                                        'Protestantism '
#                                                                        '( '
#                                                                        'Pilgrimage '
#                                                                        'of '
#                                                                        'Grace) '
#                                                                        'in '
#                                                                        'England '
#                                                                        'and '
#                                                                        'raided '
#                                                                        'all '
#                                                                        'catholic '
#                                                                        'monasteries '
#                                                                        'causing '
#                                                                        'a '
#                                                                        'revolt  '
#                                                                        'to '
#                                                                        'build '
#                                                                        'his '
#                                                                        'castles '
#                                                                        'and '
#                                                                        'pay '
#                                                                        'his '
#                                                                        'debts!',
#                                                         'textOriginal': 'Trumps '
#                                                                         'Presidency '
#                                                                         'has '
#                                                                         'similarities '
#                                                                         'to '
#                                                                         'Henry '
#                                                                         'VIII '
#                                                                         'reign '
#                                                                         'in '
#                                                                         'England! '
#                                                                         'How '
#                                                                         'he '
#                                                                         'pushed '
#                                                                         'Protestantism '
#                                                                         '( '
#                                                                         'Pilgrimage '
#                                                                         'of '
#                                                                         'Grace) '
#                                                                         'in '
#                                                                         'England '
#                                                                         'and '
#                                                                         'raided '
#                                                                         'all '
#                                                                         'catholic '
#                                                                         'monasteries '
#                                                                         'causing '
#                                                                         'a '
#                                                                         'revolt  '
#                                                                         'to '
#                                                                         'build '
#                                                                         'his '
#                                                                         'castles '
#                                                                         'and '
#                                                                         'pay '
#                                                                         'his '
#                                                                         'debts!',
#                                                         'updatedAt': '2025-10-10T23:16:28Z',
#                                                         'videoId': '5zroLgAcCmY',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': '5zroLgAcCmY'}},
#            {'etag': 'qNWZruelXuK5JdvSdlI_IEYElUk',
#             'id': 'UgyIIeo_Nl0jtBZ3eW54AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': '_F7U_dt13-u5uJRTZDDkxZDUdVU',
#                                             'id': 'UgyIIeo_Nl0jtBZ3eW54AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCipiZbOTwPv1CtNE87IPoiA'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@theRealBohemian61',
#                                                         'authorDisplayName': '@theRealBohemian61',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/pfQt0er2ILS9RJE11dMH765-RT7jlf1m5snkhsn3vYvtr1FzchHc75MymdNNFtjkuV3o5FrU0A=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2025-10-10T23:14:10Z',
#                                                         'textDisplay': 'It’s '
#                                                                        'time '
#                                                                        'for '
#                                                                        'the '
#                                                                        'citizens '
#                                                                        'to '
#                                                                        'fire '
#                                                                        'back. '
#                                                                        '🖕🤬🖕',
#                                                         'textOriginal': 'It’s '
#                                                                         'time '
#                                                                         'for '
#                                                                         'the '
#                                                                         'citizens '
#                                                                         'to '
#                                                                         'fire '
#                                                                         'back. '
#                                                                         '🖕🤬🖕',
#                                                         'updatedAt': '2025-10-10T23:14:10Z',
#                                                         'videoId': '5zroLgAcCmY',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': '5zroLgAcCmY'}},
#            {'etag': 'Xnuxaek2tPCp_rHO0Ub2qItfVMQ',
#             'id': 'UgzBm6Hx1vbVGwckut14AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'YonbiZC9ZfEYWB2F9G1vEebkX5A',
#                                             'id': 'UgzBm6Hx1vbVGwckut14AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCBBvZ9jWvpU4An_-1FgOyng'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@marklasky3555',
#                                                         'authorDisplayName': '@marklasky3555',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nMuZGwJt5qSedW0y_QUFVuF1oHduSBO6xbJovPahQ=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2025-10-10T23:14:03Z',
#                                                         'textDisplay': 'I pray '
#                                                                        'that '
#                                                                        'Gov '
#                                                                        'Pritzger '
#                                                                        'does '
#                                                                        'something '
#                                                                        'about '
#                                                                        'black '
#                                                                        'on '
#                                                                        'black '
#                                                                        'crime '
#                                                                        'in '
#                                                                        'Chicago '
#                                                                        'instead '
#                                                                        'of '
#                                                                        'just '
#                                                                        'watching '
#                                                                        'like '
#                                                                        'the '
#                                                                        'racist '
#                                                                        'he is',
#                                                         'textOriginal': 'I '
#                                                                         'pray '
#                                                                         'that '
#                                                                         'Gov '
#                                                                         'Pritzger '
#                                                                         'does '
#                                                                         'something '
#                                                                         'about '
#                                                                         'black '
#                                                                         'on '
#                                                                         'black '
#                                                                         'crime '
#                                                                         'in '
#                                                                         'Chicago '
#                                                                         'instead '
#                                                                         'of '
#                                                                         'just '
#                                                                         'watching '
#                                                                         'like '
#                                                                         'the '
#                                                                         'racist '
#                                                                         'he is',
#                                                         'updatedAt': '2025-10-10T23:14:03Z',
#                                                         'videoId': '5zroLgAcCmY',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': '5zroLgAcCmY'}},
#            {'etag': '3pr393rrDp6UvPb6CnPIQvCRLgs',
#             'id': 'UgzeX2GyRgxiaq1OZLN4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': '39Af1uav81jiTcfyGg9fHwikpBQ',
#                                             'id': 'UgzeX2GyRgxiaq1OZLN4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCY3oJLso_yBnkBLHrd7G8Zw'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@ziziroberts8041',
#                                                         'authorDisplayName': '@ziziroberts8041',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kspEogb8qMu-_k0Jani7WgOlFPJda8JSCGo5GXQjddTmw=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2025-10-10T23:13:02Z',
#                                                         'textDisplay': 'G '
#                                                                        'REEDY '
#                                                                        '<br>O '
#                                                                        'PPRESSIVE '
#                                                                        '<br>P '
#                                                                        'ERVERTS',
#                                                         'textOriginal': 'G '
#                                                                         'REEDY \n'
#                                                                         'O '
#                                                                         'PPRESSIVE \n'
#                                                                         'P '
#                                                                         'ERVERTS',
#                                                         'updatedAt': '2025-10-10T23:13:02Z',
#                                                         'videoId': '5zroLgAcCmY',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': '5zroLgAcCmY'}},
#            {'etag': 'ztZWFsdISrvVpKyE8xvi5K45wKM',
#             'id': 'Ugz9BWRid7Y2FJUlWXt4AaABAg',
#             'kind': 'youtube#commentThread',
#             'replies': {'comments': [{'etag': 'munseb98uQJRqmasfX2ucOCSoQw',
#                                       'id': 'Ugz9BWRid7Y2FJUlWXt4AaABAg.AO6tsjGnFrSAO6uAX2qjjH',
#                                       'kind': 'youtube#comment',
#                                       'snippet': {'authorChannelId': {'value': 'UCKoOXrdJ8G444u7VYhQ6olQ'},
#                                                   'authorChannelUrl': 'http://www.youtube.com/@randywheeler3914',
#                                                   'authorDisplayName': '@randywheeler3914',
#                                                   'authorProfileImageUrl': 'https://yt3.ggpht.com/arFjwRO3FDns5UA8nQztY7596DWe9i-unxfFPU26ySrl00jPM3yYth5wsRVG7r4rSYSVYac1=s48-c-k-c0x00ffffff-no-rj',
#                                                   'canRate': True,
#                                                   'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                                                   'likeCount': 0,
#                                                   'parentId': 'Ugz9BWRid7Y2FJUlWXt4AaABAg',
#                                                   'publishedAt': '2025-10-10T23:15:36Z',
#                                                   'textDisplay': '🙏🙏🙏',
#                                                   'textOriginal': '🙏🙏🙏',
#                                                   'updatedAt': '2025-10-10T23:15:36Z',
#                                                   'videoId': '5zroLgAcCmY',
#                                                   'viewerRating': 'none'}}]},
#             'snippet': {'canReply': True,
#                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'CTGh0NEGhKxBTfhYyEwac9zhlwQ',
#                                             'id': 'Ugz9BWRid7Y2FJUlWXt4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCIDI520FlEXX3D53WrLMBsA'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@paulschaller3644',
#                                                         'authorDisplayName': '@paulschaller3644',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/njpGJ9iQzNnvsx0D4B3Ni2Ynaq8C4F5fFVTPxkx5ougQ2i_XeDMMLbkMOgbl42j7tgW-03APcw=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                                                         'likeCount': 3,
#                                                         'publishedAt': '2025-10-10T23:13:02Z',
#                                                         'textDisplay': 'Catholic '
#                                                                        'Priests '
#                                                                        'don’t '
#                                                                        'believe '
#                                                                        'in the '
#                                                                        'Holy '
#                                                                        'Bible! '
#                                                                        'Jesus '
#                                                                        'Christ '
#                                                                        'has '
#                                                                        'called '
#                                                                        'the '
#                                                                        'Clergy '
#                                                                        'to '
#                                                                        'preach '
#                                                                        'the '
#                                                                        'Gospel '
#                                                                        'to '
#                                                                        'their '
#                                                                        'flock! '
#                                                                        'They’re '
#                                                                        'not '
#                                                                        'called '
#                                                                        'to be '
#                                                                        'in '
#                                                                        'lockstep '
#                                                                        'with '
#                                                                        'leftist '
#                                                                        'activist '
#                                                                        'violent '
#                                                                        'extremist '
#                                                                        'movements! '
#                                                                        'God '
#                                                                        'will '
#                                                                        'judge '
#                                                                        'those '
#                                                                        'who '
#                                                                        'mislead '
#                                                                        'his '
#                                                                        'people!',
#                                                         'textOriginal': 'Catholic '
#                                                                         'Priests '
#                                                                         'don’t '
#                                                                         'believe '
#                                                                         'in '
#                                                                         'the '
#                                                                         'Holy '
#                                                                         'Bible! '
#                                                                         'Jesus '
#                                                                         'Christ '
#                                                                         'has '
#                                                                         'called '
#                                                                         'the '
#                                                                         'Clergy '
#                                                                         'to '
#                                                                         'preach '
#                                                                         'the '
#                                                                         'Gospel '
#                                                                         'to '
#                                                                         'their '
#                                                                         'flock! '
#                                                                         'They’re '
#                                                                         'not '
#                                                                         'called '
#                                                                         'to be '
#                                                                         'in '
#                                                                         'lockstep '
#                                                                         'with '
#                                                                         'leftist '
#                                                                         'activist '
#                                                                         'violent '
#                                                                         'extremist '
#                                                                         'movements! '
#                                                                         'God '
#                                                                         'will '
#                                                                         'judge '
#                                                                         'those '
#                                                                         'who '
#                                                                         'mislead '
#                                                                         'his '
#                                                                         'people!',
#                                                         'updatedAt': '2025-10-10T23:13:02Z',
#                                                         'videoId': '5zroLgAcCmY',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 1,
#                         'videoId': '5zroLgAcCmY'}},
#            {'etag': '62tQnXeJhTcbUIPJJYD9o3KYYq8',
#             'id': 'UgxTVHhMgywHjXj6Y1l4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'yb-0qpMWyN9eBo_9sdJe9_00S1I',
#                                             'id': 'UgxTVHhMgywHjXj6Y1l4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UC1276ewkQq_3Xu_T0rajrgg'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@redfescue5935',
#                                                         'authorDisplayName': '@redfescue5935',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k3psr7itP3Y40SjFP9aWfqoMibfu3dX_wR9QWFSec=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2025-10-10T23:12:46Z',
#                                                         'textDisplay': '😂😂😂NOT '
#                                                                        'HIT IN '
#                                                                        'THE '
#                                                                        'HEAD '
#                                                                        'WITH A '
#                                                                        'PEPPER '
#                                                                        'BALL!!!!😂😂😂😂',
#                                                         'textOriginal': '😂😂😂NOT '
#                                                                         'HIT '
#                                                                         'IN '
#                                                                         'THE '
#                                                                         'HEAD '
#                                                                         'WITH '
#                                                                         'A '
#                                                                         'PEPPER '
#                                                                         'BALL!!!!😂😂😂😂',
#                                                         'updatedAt': '2025-10-10T23:12:46Z',
#                                                         'videoId': '5zroLgAcCmY',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': '5zroLgAcCmY'}},
#            {'etag': '4sOTjdlQc_I1tOzN4HfNc-UAABQ',
#             'id': 'UgwRTricpHGBVz_0SBF4AaABAg',
#             'kind': 'youtube#commentThread',
# ...
#                                                                         'the '
#                                                                         'same '
#                                                                         'time '
#                                                                         'all '
#                                                                         'over '
#                                                                         'the '
#                                                                         'world. '
#                                                                         'All '
#                                                                         'dictators '
#                                                                         'must '
#                                                                         'Fall '
#                                                                         'at '
#                                                                         'once.',
#                                                         'updatedAt': '2025-10-10T23:11:46Z',
#                                                         'videoId': '5zroLgAcCmY',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 1,
#                         'videoId': '5zroLgAcCmY'}},
#            {'etag': 'yA9D2xyGydgLwaIYFsF_0U-ftbw',
#             'id': 'Ugwm40lDS0vHRKoYe8J4AaABAg',
#             'kind': 'youtube#commentThread',
#             'snippet': {'canReply': True,
#                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                         'isPublic': True,
#                         'topLevelComment': {'etag': 'oKP5P9Qbg99UL1kCuGmbYnqeEUQ',
#                                             'id': 'Ugwm40lDS0vHRKoYe8J4AaABAg',
#                                             'kind': 'youtube#comment',
#                                             'snippet': {'authorChannelId': {'value': 'UCMSwgqDRKHQo0QW5QPms8-g'},
#                                                         'authorChannelUrl': 'http://www.youtube.com/@jeremiahjohnson7515',
#                                                         'authorDisplayName': '@jeremiahjohnson7515',
#                                                         'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k3fREiMwODCB1M30TB18t8z3vDs0d_R38MqxdRLpQ=s48-c-k-c0x00ffffff-no-rj',
#                                                         'canRate': True,
#                                                         'channelId': 'UCaXkIU1QidjPwiAYu6GcHjg',
#                                                         'likeCount': 0,
#                                                         'publishedAt': '2025-10-10T23:11:41Z',
#                                                         'textDisplay': 'The '
#                                                                        'irony '
#                                                                        'of '
#                                                                        'Hegseth '
#                                                                        'calling '
#                                                                        'for a '
#                                                                        'more '
#                                                                        'efficient '
#                                                                        'military '
#                                                                        'works '
#                                                                        'against '
#                                                                        'him. '
#                                                                        'The '
#                                                                        'Military '
#                                                                        'makes '
#                                                                        'an '
#                                                                        'oath '
#                                                                        'to the '
#                                                                        'Constitution, '
#                                                                        'not a '
#                                                                        'President, '
#                                                                        'not a '
#                                                                        'region, '
#                                                                        'not a '
#                                                                        'party, '
#                                                                        'to the '
#                                                                        'People. '
#                                                                        '<br><br>Trump '
#                                                                        'has '
#                                                                        'eroded '
#                                                                        'the '
#                                                                        'separation '
#                                                                        'of '
#                                                                        'powers: '
#                                                                        'the '
#                                                                        'Legistlative, '
#                                                                        'Judicial '
#                                                                        'and '
#                                                                        'the '
#                                                                        'Executive '
#                                                                        'branch '
#                                                                        'have '
#                                                                        'all '
#                                                                        'succeeded.<br><br>There&#39;s '
#                                                                        'only '
#                                                                        'two '
#                                                                        'branches '
#                                                                        'left: '
#                                                                        'The '
#                                                                        'people '
#                                                                        'and '
#                                                                        'the '
#                                                                        'military. '
#                                                                        'The '
#                                                                        'people '
#                                                                        'are '
#                                                                        'losing. '
#                                                                        'Main '
#                                                                        'stream '
#                                                                        'media, '
#                                                                        'protesters, '
#                                                                        'judges, '
#                                                                        'politicians '
#                                                                        'are '
#                                                                        'all '
#                                                                        'ANTIFA '
#                                                                        'if '
#                                                                        'Trump '
#                                                                        'says '
#                                                                        'they '
#                                                                        'are.<br><br>Live '
#                                                                        'by '
#                                                                        'your '
#                                                                        'oath.',
#                                                         'textOriginal': 'The '
#                                                                         'irony '
#                                                                         'of '
#                                                                         'Hegseth '
#                                                                         'calling '
#                                                                         'for a '
#                                                                         'more '
#                                                                         'efficient '
#                                                                         'military '
#                                                                         'works '
#                                                                         'against '
#                                                                         'him. '
#                                                                         'The '
#                                                                         'Military '
#                                                                         'makes '
#                                                                         'an '
#                                                                         'oath '
#                                                                         'to '
#                                                                         'the '
#                                                                         'Constitution, '
#                                                                         'not a '
#                                                                         'President, '
#                                                                         'not a '
#                                                                         'region, '
#                                                                         'not a '
#                                                                         'party, '
#                                                                         'to '
#                                                                         'the '
#                                                                         'People. \n'
#                                                                         '\n'
#                                                                         'Trump '
#                                                                         'has '
#                                                                         'eroded '
#                                                                         'the '
#                                                                         'separation '
#                                                                         'of '
#                                                                         'powers: '
#                                                                         'the '
#                                                                         'Legistlative, '
#                                                                         'Judicial '
#                                                                         'and '
#                                                                         'the '
#                                                                         'Executive '
#                                                                         'branch '
#                                                                         'have '
#                                                                         'all '
#                                                                         'succeeded.\n'
#                                                                         '\n'
#                                                                         "There's "
#                                                                         'only '
#                                                                         'two '
#                                                                         'branches '
#                                                                         'left: '
#                                                                         'The '
#                                                                         'people '
#                                                                         'and '
#                                                                         'the '
#                                                                         'military. '
#                                                                         'The '
#                                                                         'people '
#                                                                         'are '
#                                                                         'losing. '
#                                                                         'Main '
#                                                                         'stream '
#                                                                         'media, '
#                                                                         'protesters, '
#                                                                         'judges, '
#                                                                         'politicians '
#                                                                         'are '
#                                                                         'all '
#                                                                         'ANTIFA '
#                                                                         'if '
#                                                                         'Trump '
#                                                                         'says '
#                                                                         'they '
#                                                                         'are.\n'
#                                                                         '\n'
#                                                                         'Live '
#                                                                         'by '
#                                                                         'your '
#                                                                         'oath.',
#                                                         'updatedAt': '2025-10-10T23:13:27Z',
#                                                         'videoId': '5zroLgAcCmY',
#                                                         'viewerRating': 'none'}},
#                         'totalReplyCount': 0,
#                         'videoId': '5zroLgAcCmY'}}],
#  'kind': 'youtube#commentThreadListResponse',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNLZ2dHQUFTQlFpSklCZ0FFZ1VJblNBWUFSSUZDSWdnR0FBU0JRaUhJQmdBSWc0S0RBaXNwYWJIQmhENHRvWGFBdw==',
#  'pageInfo': {'resultsPerPage': 20, 'totalResults': 20}}

# %% [markdown]
# ### 1.5 Commenter Details Retrieval
#
# We should get insights on the commenter's channel, such as
# - account creation date
# - account subscriber count (if applicable)
# - account country origin

# %%
@api_status_handler
def get_commenter_details(account_id: str):
    request = youtube.channels().list(
        part="id,snippet,statistics",
        id=account_id
    )
    response = request.execute()
    
    return response

# %% [markdown]
# ## 2. Comment API Scraping
#
# We will construct a more involed scraper, utilizing what we found above

# %%
class CommentData(TypedDict):
    author_display_name: str
    author_channel_id: str
    video_channel_id: str
    video_id: str
    channel_id: str
    text: str
    like_count: int
    updated_at: str | datetime
    published_at: str | datetime
    is_reply: bool
    
    commenter_created_at: str | datetime
    commenter_sub_count: int
    commenter_video_count: int
    

def scraper():
    """
    Retrieves comments from the 5 most recent videos from all channels.
    """
    all_data = []
    for channel_handle in CHANNEL_HANDLES:
        print(f"="*80)
        print(f"\tRetrieving comments from: {channel_handle:^30}")
        print(f"="*80)
        
        # Get channel info
        channel_response = get_channel(channel_handle)
        if channel_response["status_code"] == 200:
            channel = channel_response["data"]
        else:
            print(f"Unable to retrieve channel data; skipping...")
            continue
        
        # Retrieve uploads ID and get videos
        playlist_id = channel["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
        uploads_response = get_channel_uploads(playlist_id)     # Should retrieve 5 videos per page, 
                                                                #   as per default pagination settings                      
        if uploads_response["status_code"] == 200:
            uploads = uploads_response["data"]["items"]
        else:
            print(f"Unable to process {channel_handle} uploads playlist; skipping...")
            continue
        
        comments = process_videos(uploads)
        all_data.extend(comments)
        
    return all_data
        

def process_videos(uploads: List[Dict[str, Any]]) -> List[CommentData]:
    """
    Helper function for parsing videos from a list of uploads from a channel.
    
    Args:
        uploads (List[Dict]): A list of video items, represented as a Dict
    
    Returns:
        List[CommentData]: A list of all retrieved comments
    """
    comments = []
    for video_entry in uploads:
        # Get an entry's video ID
        video_id = video_entry["contentDetails"]["videoId"]
        video_title = video_entry["snippet"]["title"]
        
        # Use video ID for comment thread
        comment_thread_response = get_comment_thread(video_id)
        if comment_thread_response["status_code"] == 200:
            comment_thread = comment_thread_response["data"]["items"]
        else:
            print(f"Video [{video_id}] has comments disabled. Skipping...")
            continue
        
        # Retrieve all comments from video's comment thread
        video_comments = process_comment_thread(comment_thread)
        comments.extend(video_comments)
        
    return comments


def process_comment_thread(comment_thread: List[Dict[str, Any]]) -> List[CommentData]:
    """
    Helper function for parsing comments from a single video's comment thread.
    Retrieves head comments and their replies, if any.
    
    Args:
        comment_thread (List[Dict]): A list of comments from the comment thread
        
    Returns:
        List[CommentData]: A list of retrieved comments
    """
    comments = []
    for head_comment in comment_thread:
        # Get video ID
        video_id = head_comment["snippet"]["videoId"]
        
        # Get head comment's comment data
        comment = head_comment["snippet"]["topLevelComment"]
        comment = process_comment(comment, video_id=video_id, is_reply=False)
        comments.append(comment)
        
        # Get head comment's ID (for replies)
        head_comment_id = head_comment["snippet"]["topLevelComment"]["id"]
        
        # If the head comment has replies, get those comments
        replies = head_comment.get("replies", {})
        thread_replies = replies.get("comments", [])
        for reply in thread_replies:
            comment = process_comment(reply, video_id=video_id, is_reply=True, head_comment_id=head_comment_id)
            comments.append(comment)
    
    return comments

def process_comment(comment: Dict[str, Any], video_id: str, is_reply: bool, head_comment_id: Optional[str] = None) -> CommentData:
    """
    Parses a single comment from a comment thread
    
    Args:
        comment: The Comment Resource (https://developers.google.com/youtube/v3/docs/comments#resource)
        video_id: The underlying video in which the comment exists
        is_reply: Whether or not the comment is a reply within a thread
        
    Returns:
        CommentData: The aggregated data retrieved
    """
    snippet = comment["snippet"]
    
    author_display_name = snippet["authorDisplayName"]
    like_count = snippet["likeCount"]
    text = snippet["textOriginal"]
    author_channel_id = snippet["authorChannelId"]["value"]
    video_channel_id = snippet["channelId"]
    updated_at = snippet["updatedAt"]
    published_at = snippet["publishedAt"]
    is_updated = updated_at == published_at
    
    account_details_response = get_commenter_details(account_id=author_channel_id)
    
    if account_details_response["status_code"] == 200:
        account_details = account_details_response["data"]["items"][0]
        
        commenter_created_at = account_details["snippet"]["publishedAt"],
        is_hidden_sub_count = account_details["statistics"]["hiddenSubscriberCount"]
        commenter_sub_count = account_details["statistics"]["subscriberCount"] \
            if not is_hidden_sub_count else 0
        commenter_video_count = account_details["statistics"]["videoCount"]
        
        return CommentData(
            author_display_name = author_display_name,
            author_channel_id = author_channel_id,
            like_count = like_count,
            text = text,
            video_id = video_id,
            video_channel_id = video_channel_id,
            updated_at = updated_at,
            published_at = published_at,
            is_updated = is_updated,
            is_reply = is_reply,
            head_comment_id = head_comment_id,
            commenter_created_at = commenter_created_at,
            commenter_is_hidden_sub_count = is_hidden_sub_count,
            commenter_sub_count = commenter_sub_count,
            commenter_video_count = commenter_video_count
        )
    else:
        print(f"Unable to retrieve commenter account info for: {author_display_name}")
        return CommentData(
            author_display_name = author_display_name,
            author_channel_id = author_channel_id,
            like_count = like_count,
            text = text,
            video_id = video_id,
            video_channel_id = video_channel_id,
            updated_at = updated_at,
            published_at = published_at,
            is_updated = is_updated,
            is_reply = is_reply,
            head_comment_id = head_comment_id,
        )
    
        
scraper_results = scraper()
# Out:
# ================================================================================
# 	Retrieving comments from:             msnbc
# ================================================================================
# ================================================================================
# 	Retrieving comments from:              cnn
# ================================================================================
# ================================================================================
# 	Retrieving comments from:            FoxNews
# ================================================================================
# ================================================================================
# 	Retrieving comments from:            Reuters
# ================================================================================
# HTTP Error 403: {
#   "error": {
#     "code": 403,
#     "message": "The video identified by the \u003ccode\u003e\u003ca href=\"/youtube/v3/docs/commentThreads/list#videoId\"\u003evideoId\u003c/a\u003e\u003c/code\u003e parameter has disabled comments.",
#     "errors": [
#       {
#         "message": "The video identified by the \u003ccode\u003e\u003ca href=\"/youtube/v3/docs/commentThreads/list#videoId\"\u003evideoId\u003c/a\u003e\u003c/code\u003e parameter has disabled comments.",
#         "domain": "youtube.commentThread",
#         "reason": "commentsDisabled",
#         "location": "videoId",
#         "locationType": "parameter"
#       }
#     ]
#   }
# }
#
# Comments disabled or quota exceeded
# Video [og0hOz3indU] has comments disabled. Skipping...
# HTTP Error 403: {
#   "error": {
#     "code": 403,
#     "message": "The video identified by the \u003ccode\u003e\u003ca href=\"/youtube/v3/docs/commentThreads/list#videoId\"\u003evideoId\u003c/a\u003e\u003c/code\u003e parameter has disabled comments.",
#     "errors": [
#       {
#         "message": "The video identified by the \u003ccode\u003e\u003ca href=\"/youtube/v3/docs/commentThreads/list#videoId\"\u003evideoId\u003c/a\u003e\u003c/code\u003e parameter has disabled comments.",
#         "domain": "youtube.commentThread",
#         "reason": "commentsDisabled",
#         "location": "videoId",
#         "locationType": "parameter"
#       }
#     ]
#   }
# }
#
# Comments disabled or quota exceeded
# Video [tcAqVW1rxkA] has comments disabled. Skipping...
# HTTP Error 403: {
#   "error": {
#     "code": 403,
#     "message": "The video identified by the \u003ccode\u003e\u003ca href=\"/youtube/v3/docs/commentThreads/list#videoId\"\u003evideoId\u003c/a\u003e\u003c/code\u003e parameter has disabled comments.",
#     "errors": [
#       {
#         "message": "The video identified by the \u003ccode\u003e\u003ca href=\"/youtube/v3/docs/commentThreads/list#videoId\"\u003evideoId\u003c/a\u003e\u003c/code\u003e parameter has disabled comments.",
#         "domain": "youtube.commentThread",
#         "reason": "commentsDisabled",
#         "location": "videoId",
#         "locationType": "parameter"
#       }
#     ]
#   }
# }
#
# Comments disabled or quota exceeded
# Video [7JHbDnxJV-Y] has comments disabled. Skipping...
# HTTP Error 403: {
#   "error": {
#     "code": 403,
#     "message": "The video identified by the \u003ccode\u003e\u003ca href=\"/youtube/v3/docs/commentThreads/list#videoId\"\u003evideoId\u003c/a\u003e\u003c/code\u003e parameter has disabled comments.",
#     "errors": [
#       {
#         "message": "The video identified by the \u003ccode\u003e\u003ca href=\"/youtube/v3/docs/commentThreads/list#videoId\"\u003evideoId\u003c/a\u003e\u003c/code\u003e parameter has disabled comments.",
#         "domain": "youtube.commentThread",
#         "reason": "commentsDisabled",
#         "location": "videoId",
#         "locationType": "parameter"
#       }
#     ]
#   }
# }
#
# Comments disabled or quota exceeded
# Video [HVHQLj38lsM] has comments disabled. Skipping...
# HTTP Error 403: {
#   "error": {
#     "code": 403,
#     "message": "The video identified by the \u003ccode\u003e\u003ca href=\"/youtube/v3/docs/commentThreads/list#videoId\"\u003evideoId\u003c/a\u003e\u003c/code\u003e parameter has disabled comments.",
#     "errors": [
#       {
#         "message": "The video identified by the \u003ccode\u003e\u003ca href=\"/youtube/v3/docs/commentThreads/list#videoId\"\u003evideoId\u003c/a\u003e\u003c/code\u003e parameter has disabled comments.",
#         "domain": "youtube.commentThread",
#         "reason": "commentsDisabled",
#         "location": "videoId",
#         "locationType": "parameter"
#       }
#     ]
#   }
# }
#
# Comments disabled or quota exceeded
# Video [H5ymYYKJCSQ] has comments disabled. Skipping...
# ================================================================================
# 	Retrieving comments from:        briantylercohen
# ================================================================================
# ================================================================================
# 	Retrieving comments from:         DailyWirePlus
# ================================================================================
# ================================================================================
# 	Retrieving comments from:            ABCNews
# ================================================================================
# HTTP Error 403: {
#   "error": {
#     "code": 403,
#     "message": "The video identified by the \u003ccode\u003e\u003ca href=\"/youtube/v3/docs/commentThreads/list#videoId\"\u003evideoId\u003c/a\u003e\u003c/code\u003e parameter has disabled comments.",
#     "errors": [
#       {
#         "message": "The video identified by the \u003ccode\u003e\u003ca href=\"/youtube/v3/docs/commentThreads/list#videoId\"\u003evideoId\u003c/a\u003e\u003c/code\u003e parameter has disabled comments.",
#         "domain": "youtube.commentThread",
#         "reason": "commentsDisabled",
#         "location": "videoId",
#         "locationType": "parameter"
#       }
#     ]
#   }
# }
#
# Comments disabled or quota exceeded
# Video [MOU0J_EgUmA] has comments disabled. Skipping...
# ================================================================================
# 	Retrieving comments from:         TuckerCarlson
# ================================================================================

# %%
len(scraper_results)
# Out:
# 604
